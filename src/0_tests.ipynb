# %%
import json
import requests
import re

use_tor = False

# %% [markdown]
# ## GDELT QUERYING:

# %%
def api_url_constructor(query,
                        mode='artlist',
                        format='json',
                        records=250,
                        start_date=20200101000000,
                        end_date=20220131235959):
    query = query.replace(' ', '%20')
    url_head = "https://api.gdeltproject.org/api/v2/doc/doc?"
    body = f"query={query}&mode={mode}&format={format}&maxrecords={records}"
    params = f"&startdatetime={start_date}&enddatetime={end_date}"
    trans = "&trans=googtrans"
    
    full_url = url_head + body + params + trans
    
    return full_url


def tor_request(url_input):
    '''
    Solo si tienes TOR habilitado en tu ordenador
    https://medium.com/@jasonrigden/using-tor-with-the-python-request-library-79015b2606cb 
    
    Usa la red TOR para hacer peticiones desde IPs aleatorias simulando navegadores.
    Esto anula los límites de llamadas a APIs gratuitas, que suelen fijarse en IP.
    '''
    tor_proxy = {
        'http': 'socks5://127.0.0.1:9050',
        'https': 'socks5://127.0.0.1:9050'
    }

    session = requests.session()
    session.proxies = tor_proxy
    session.headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    socks.set_default_proxy(socks.SOCKS5, "127.0.0.1", 9050)
    socket.socket = socks.socksocket

    r = session.get(url_input)
    return r


if use_tor:
    socks.set_default_proxy(socks.SOCKS5, "127.0.0.1", 9050)
    socket.socket = socks.socksocket

def query_cleaner(query):
    ''' 
    La API de GDELT no acepta caracteres especiales en la query.
    Los sustituimos por espacios.
    '''
    patrones = r'[^\w\s\"\(\)]+'
    query = re.sub(patrones, ' ', query)
    
    # Terminos de denominacion empresarial que no son utiles:
    terminos_eliminar = r' Inc\.| Corp\.| Ltd\.| PLC| Co\.| S\.A\.|& KGaA|& KgaA|Co\., Ltd\.|P L C|\(publ\)|\.Com|\.com|A/S|AB|AE|AG|AS|ASA|Abp|CORP|Co|Corp|GmbH & KGaA|Inc|Inc\.|KGaA|LLC|LP|LPG|LTD|Ltd|MFG|NL|NV|Oyj|PLC|Plc|RL|SA|SE|SGPS|SpA|plc|rp'

    query = re.sub(terminos_eliminar,
                    '',
                    query,
                    flags=re.IGNORECASE)
    
    # Quitamos dobles espacios:
    query = re.sub(r'\s+', ' ', query)
    return query


def name_amplifier(name):
    '''
    A veces los nombres tienen demasiadas palabras.
    Esto hace la query muy específica y puede obviar resultados.
    Añadimos permutaciones de las palabras del nombre con 'OR'
    '''
    nombre_query = name # Por defecto, el nombre original
    
    if name.split(' ')>2:
        nombre_corto = ''
        nombre_corto = ' '.join(name.split()[:3])
        nombre_corto_2 = ' '.join(name.split()[:2])
        # Unimos con 'OR' los diferentes nombres:
        nombre_query = f'("{name}" OR "{nombre_corto}" OR "{nombre_corto_2}")'
    
    return nombre_query


def query_completion(query, positives, negatives):
    '''
    Función que recibe una lista de positivos(tuplas) y otra de negativos.
    Los positivos se añaden a la query como:
    'AND ("positivo1" OR "positivo1_alt" OR ...)'
    'AND ("positivo2" OR "positivo2_alt" OR ...)'
    Los negativos se añaden como 'AND -negativo1 AND -negativo2 ...'
    '''
    # Si hay positivos, los añadimos a la query:
    if positives:
        positives = ''
        for p in positives:
            # Si solo hay un elemento en la tupla, no hace falta añadir OR:
            positive_to_add = p[0]
            
            # Si hay más de un elemento, añadimos OR:
            if len(p)>1:
                for i in p[1:]:
                    positive_to_add += f' OR "{i}"'
            
            # El formato es AND ("positivo1" OR "positivo1_alt" OR ...)
            positives += f'AND ({positive_to_add})'

# %%
positives = [('Bayer', 'Bayer AG', 'Bayerische Motoren Werke AG', 'BMW AG', 'BMW'),
             ('Acerinox', 'Acerinox S.A.', 'Acerinox SA')]

# %%
if positives:
    positives_query = ''
    for p in positives:
        # Si solo hay un elemento en la tupla, no hace falta añadir OR:
        positive_to_add = f'"{p[0]}"'
        
        # Si hay más de un elemento, añadimos OR:
        if len(p)>1:
            for i in p[1:]:
                positive_to_add += f' OR "{i}"'
        
        # El formato es AND ("positivo1" OR "positivo1_alt" OR ...)
        positives_query += f'AND ({positive_to_add})'

positives_query
# Out:
# 'AND ("Bayer" OR "Bayer AG" OR "Bayerische Motoren Werke AG" OR "BMW AG" OR "BMW")AND ("Acerinox" OR "Acerinox S.A." OR "Acerinox SA")'

# %%
api_url_constructor('Acerinox')
# Out:
# 'https://api.gdeltproject.org/api/v2/doc/doc?query=Acerinox&mode=artlist&format=json&maxrecords=250&startdatetime=20200101000000&enddatetime=20220131235959&trans=googtrans'

# %%
requests.request

# %%
respuesta = requests.get(url=api_url_constructor('Acerinox'))

# %%
respuesta.json()
# Out:
# {'articles': [{'url': 'https://www.marketwatch.com/articles/acerinox-stock-price-outlook-51639175858',
#    'url_mobile': '',
#    'title': 'Acerinox Stock : Huge Demand for Appliances , Autos Could Help Shares 50 % ',
#    'seendate': '20211212T173000Z',
#    'socialimage': 'https://images.barrons.com/im-448699/social',
#    'domain': 'marketwatch.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/dividendos/acerinox-aprueba-una-recompra-de-acciones-del-n-492947',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/acerinox-aprueba-una-recompra-de-acciones-del-n-492947',
#    'title': 'Acerinox aprueba una recompra de acciones del 4 % de la compaa',
#    'seendate': '20211220T114500Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/images/amp/bolsa-madrid-7.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.marketwatch.com/articles/stainless-steel-stock-acerinox-51639175858',
#    'url_mobile': '',
#    'title': 'Demand Is High for Autos and Appliances . That Helps This Stainless Steelmaker . ',
#    'seendate': '20211211T004500Z',
#    'socialimage': 'https://images.barrons.com/im-448699/social',
#    'domain': 'marketwatch.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.marketwatch.com/articles/demand-is-high-for-autos-and-appliances-that-helps-this-stainless-steelmaker-51639176007',
#    'url_mobile': '',
#    'title': 'Demand Is High for Autos and Appliances . That Helps This Stainless Steelmaker . ',
#    'seendate': '20211210T230000Z',
#    'socialimage': 'https://images.barrons.com/im-448699/social',
#    'domain': 'marketwatch.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/acerinox-consolida-los-10-euros-a-pesar-de-la-n-491865',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/acerinox-consolida-los-10-euros-a-pesar-de-la-n-491865',
#    'title': 'Acerinox : consolida los 10 euros a pesar de la rebaja de Jefferies',
#    'seendate': '20211208T071500Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/graficos_dentro/202112/semana_1/acerinox_1.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://cincodias.elpais.com/cincodias/2021/12/20/companias/1639995173_805406.html',
#    'url_mobile': 'https://cincodias.elpais.com/cincodias/2021/12/20/companias/1639995173_805406.amp.html',
#    'title': 'Acerinox aprueba un plan de recompra del 4 % de sus acciones | Compaas',
#    'seendate': '20211220T110000Z',
#    'socialimage': 'https://d500.epimg.net/cincodias/imagenes/2021/12/20/companias/1639995173_805406_1639995355_rrss_normal.jpg',
#    'domain': 'cincodias.elpais.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/acerinox-vuelve-a-reactivarse-con-potencial-del-n-489635',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/acerinox-vuelve-a-reactivarse-con-potencial-del-n-489635',
#    'title': 'Acerinox vuelve a reactivarse con potencial del 46 % ',
#    'seendate': '20211112T053000Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/graficos_dentro/202111/semana_2/acerinox_ok.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://charter97.org/ru/news/2022/1/10/450542/',
#    'url_mobile': 'https://k2rwgs.c97.org/ru/news/2022/1/10/450542/',
#    'title': 'Россия выдала режиму Лукашенко еще одного белоруса',
#    'seendate': '20220110T133000Z',
#    'socialimage': 'https://i.c97.org/ai/449562/aux-head-1641042467-20220101_podbolotnikov_360.jpg',
#    'domain': 'charter97.org',
#    'language': 'Russian',
#    'sourcecountry': 'Belarus'},
#   {'url': 'https://www.elboletin.com/espaldarazo-para-acerinox-jp-morgan-espera-que-practicamente-duplique-su-precio/',
#    'url_mobile': 'https://www.elboletin.com/espaldarazo-para-acerinox-jp-morgan-espera-que-practicamente-duplique-su-precio/amp/',
#    'title': 'Espaldarazo para Acerinox : JP Morgan espera que prácticamente duplique su precio',
#    'seendate': '20211213T121500Z',
#    'socialimage': 'https://www.elboletin.com/wp-content/uploads/2020/07/www.elboletin.com_fotos_1_136961_acerinox.jpg',
#    'domain': 'elboletin.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/mercados/2021/12/14/61b8eba0e5fdea24148b460a.html',
#    'url_mobile': 'https://amp.expansion.com/mercados/2021/12/14/61b8eba0e5fdea24148b460a.html',
#    'title': 'Los Charts de Hódar : ArcelorMittal , Telefónica y Acerinox',
#    'seendate': '20211214T203000Z',
#    'socialimage': 'https://phantom-expansion.unidadeditorial.es/eaa14027c132fb99af1a7a005f6013f8/crop/0x0/2044x1363/resize/1200/f/jpg/assets/multimedia/imagenes/2020/03/18/15845254591369.jpg',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/mercados/2022/01/27/61f1b3aa468aeb43078b4594.html',
#    'url_mobile': 'https://amp.expansion.com/mercados/2022/01/27/61f1b3aa468aeb43078b4594.html',
#    'title': 'Los Charts de Carmen Ramos : ACS , Acerinox y BBVA',
#    'seendate': '20220127T034500Z',
#    'socialimage': 'https://phantom-expansion.unidadeditorial.es/2529d861a28129f7ce9ea030ace55329/crop/0x0/2047x1365/resize/1200/f/jpg/assets/multimedia/imagenes/2022/01/26/16432245023199.jpg',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.europapress.es/economia/noticia-acerinox-aprueba-plan-recompra-acciones-amortizacion-capital-20211220093859.html',
#    'url_mobile': 'https://amp.europapress.es/economia/noticia-acerinox-aprueba-plan-recompra-acciones-amortizacion-capital-20211220093859.html',
#    'title': 'Acerinox aprueba un plan de recompra de acciones para amortización de hasta un 4 % de su capital',
#    'seendate': '20211220T100000Z',
#    'socialimage': 'https://img.europapress.es/fotoweb/fotonoticia_20211220093859_1200.jpg',
#    'domain': 'europapress.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://es.noticias.yahoo.com/acerinox-vuelve-reactivarse-potencial-46-043000403.html',
#    'url_mobile': 'https://es.noticias.yahoo.com/amphtml/acerinox-vuelve-reactivarse-potencial-46-043000403.html',
#    'title': 'Acerinox vuelve a reactivarse con potencial del 46 % ',
#    'seendate': '20211114T021500Z',
#    'socialimage': 'https://s.yimg.com/uu/api/res/1.2/XmF2Q9Nt3aQolzyA5_d2rQ--~B/aD02MDA7dz04NTg7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/es/estrategias_de_inversi_n_556/420e97872a1e915bfd183981e5b6b343',
#    'domain': 'es.noticias.yahoo.com',
#    'language': 'Spanish',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/invertir-en-el-mercado-continuo-tres-valores-para-n-490085',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/invertir-en-el-mercado-continuo-tres-valores-para-n-490085',
#    'title': 'Mercado Continuo : mejores valores para invertir por técnico y potencial',
#    'seendate': '20211117T111500Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/native/mercado_alcista.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/blogs/escenario-tecnico/2022/01/29/que-mensaje-nos-lanzan-acerinox-y.html',
#    'url_mobile': 'https://amp.expansion.com/blogs/escenario-tecnico/2022/01/29/que-mensaje-nos-lanzan-acerinox-y.html',
#    'title': 'Escenario técnico de mercados - ¿ Qué mensaje nos lanzan Acerinox y ArcelorMittal ? ',
#    'seendate': '20220129T144500Z',
#    'socialimage': 'https://e00-expansion.uecdn.es/assets/desktop/master/img/blogs/foto_peq_gerardoortega.png',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/ahorro/2022/01/19/61e74545e5fdeacb1f8b467e.html',
#    'url_mobile': 'https://amp.expansion.com/ahorro/2022/01/19/61e74545e5fdeacb1f8b467e.html',
#    'title': 'Cinco valores del Ibex dan señales de romper al alza',
#    'seendate': '20220119T020000Z',
#    'socialimage': 'https://phantom-expansion.unidadeditorial.es/946c631a598f6c169ed89f3587f12b41/crop/178x0/1762x1057/resize/1200/f/jpg/assets/multimedia/imagenes/2021/12/16/16396890562146.jpg',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/mercados/2022/01/18/61e5fc9c468aeb36318b470d.html',
#    'url_mobile': 'https://amp.expansion.com/mercados/2022/01/18/61e5fc9c468aeb36318b470d.html',
#    'title': 'Más de la mitad de valores del Ibex deja atrás la  mini crisi de Ómicron',
#    'seendate': '20220118T020000Z',
#    'socialimage': 'https://phantom-expansion.unidadeditorial.es/3e4e7ced6b221a3fe1c0eefd2c3a6fc3/crop/211x0/1937x1150/resize/1200/f/jpg/assets/multimedia/imagenes/2022/01/14/16421431350815.jpg',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.diariosigloxxi.com/texto-s/mostrar/437711/sabadell-concede-prestamo-acerinox-205-millones',
#    'url_mobile': '',
#    'title': 'El Sabadell concede un préstamo a Acerinox por 205 millones',
#    'seendate': '20211223T184500Z',
#    'socialimage': 'http://www.diariosigloxxi.com/images/',
#    'domain': 'diariosigloxxi.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elboletin.com/acerinox-aprueba-un-plan-de-recompra-de-acciones-de-hasta-un-4-de-su-capital/',
#    'url_mobile': 'https://www.elboletin.com/acerinox-aprueba-un-plan-de-recompra-de-acciones-de-hasta-un-4-de-su-capital/amp/',
#    'title': 'Acerinox aprueba un plan de recompra de acciones de hasta un 4 % de su capital',
#    'seendate': '20211221T090000Z',
#    'socialimage': 'https://www.elboletin.com/wp-content/uploads/2020/05/www.elboletin.com_fotos_1_131462_acerinox.jpg',
#    'domain': 'elboletin.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/empresas/banca/2021/12/07/61aea977e5fdeab4158b4617.html',
#    'url_mobile': 'https://amp.expansion.com/empresas/banca/2021/12/07/61aea977e5fdeab4158b4617.html',
#    'title': 'Telefónica , Repsol , Inditex y Naturgy se protegen con su aseguradora cautiva',
#    'seendate': '20211207T024500Z',
#    'socialimage': 'https://phantom-expansion.unidadeditorial.es/0e27e7fb3c62422fe0e65d974b99ae64/crop/0x0/2031x1354/resize/1200/f/jpg/assets/multimedia/imagenes/2021/12/07/16388365386821.jpg',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lainformacion.com/mercados-y-bolsas/mejores-acciones-ibex-2022-analistas/2856874/',
#    'url_mobile': 'https://amp.lainformacion.com/mercados-y-bolsas/mejores-acciones-ibex-2022-analistas/2856874/',
#    'title': 'Aquí están las mejores acciones del Ibex para el 2022 en el consenso de analistas',
#    'seendate': '20220101T123000Z',
#    'socialimage': 'https://imagenes.lainformacion.com/files/og_lainfo/uploads/imagenes/2021/12/31/la-mejores-acciones-para-2022-segun-el-consenso-de-analistas.jpeg',
#    'domain': 'lainformacion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.marketscreener.com/quote/stock/ACERINOX-S-A-141121/news/EU-imposes-tariffs-on-stainless-steel-from-India-Indonesia-37073309/',
#    'url_mobile': 'https://www.marketscreener.com/amp/quote/stock/ACERINOX-S-A-141121/news/EU-imposes-tariffs-on-stainless-steel-from-India-Indonesia-37073309/',
#    'title': 'EU imposes tariffs on stainless steel from India , Indonesia',
#    'seendate': '20211119T110000Z',
#    'socialimage': 'https://img.zonebourse.com/reuters/2021-11-18T171417Z_1_LYNXMPEHAH0ZI_RTROPTP_3_INDIA-ECONOMY-BUDGET.JPG',
#    'domain': 'marketscreener.com',
#    'language': 'English',
#    'sourcecountry': ''},
#   {'url': 'https://noticiasbancarias.com/bancos/24/12/2021/banco-sabadell-concede-un-prestamo-de-205-millones-de-euros-a-acerinox/251446.html',
#    'url_mobile': 'https://noticiasbancarias.com/bancos/24/12/2021/banco-sabadell-concede-un-prestamo-de-205-millones-de-euros-a-acerinox/251446.html?amp',
#    'title': 'Banco Sabadell concede un préstamo de 205 millones de euros a Acerinox',
#    'seendate': '20211224T213000Z',
#    'socialimage': '',
#    'domain': 'noticiasbancarias.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.marketscreener.com/quote/stock/ACERINOX-S-A-141121/news-strategies/A-trend-reversal-can-be-anticipated-36937411/',
#    'url_mobile': 'https://www.marketscreener.com/amp/quote/stock/ACERINOX-S-A-141121/news-strategies/A-trend-reversal-can-be-anticipated-36937411/',
#    'title': 'Acerinox S . A . : A trend reversal can be anticipated',
#    'seendate': '20211108T140000Z',
#    'socialimage': '',
#    'domain': 'marketscreener.com',
#    'language': 'English',
#    'sourcecountry': ''},
#   {'url': 'https://www.elperiodico.com/es/economia/20211111/bolsa-11-noviembre-2021-12838134',
#    'url_mobile': 'https://amp.elperiodico.com/es/economia/20211111/bolsa-11-noviembre-2021-12838134',
#    'title': 'La bolsa del 11 de noviembre de 2021',
#    'seendate': '20211112T000000Z',
#    'socialimage': 'https://est.elperiodico.com/ep-static/img/default-es-1260x708.jpg',
#    'domain': 'elperiodico.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://prnoticias.com/2021/12/13/ibex-35-lunes-13-diciembre-previsiones-alcistas/',
#    'url_mobile': '',
#    'title': 'El Ibex estrena la semana con previsiones alcistas',
#    'seendate': '20211213T141500Z',
#    'socialimage': 'https://prnoticias.com/wp-content/uploads/2019/08/26dba68c591771aa70878d8dc66a6209.jpg',
#    'domain': 'prnoticias.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elperiodico.com/es/economia/20220121/bolsa-viernes-21-enero-2022-13132997',
#    'url_mobile': 'https://amp.elperiodico.com/es/economia/20220121/bolsa-viernes-21-enero-2022-13132997',
#    'title': 'La bolsa del viernes 21 de enero de 2022',
#    'seendate': '20220121T231500Z',
#    'socialimage': 'https://est.elperiodico.com/ep-static/img/default-es-1260x708.jpg',
#    'domain': 'elperiodico.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.reuters.com/markets/asia/eu-imposes-tariffs-stainless-steel-india-indonesia-2021-11-18/',
#    'url_mobile': '',
#    'title': 'EU imposes tariffs on stainless steel from India , Indonesia',
#    'seendate': '20211118T200000Z',
#    'socialimage': 'https://www.reuters.com/resizer/Bv5FiQf-HcxxFWziJdjnQOfJWbg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/QDYUXW4TF5KQJNAZZM7P42Z7BQ.jpg',
#    'domain': 'reuters.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.canalsur.es/noticias/andaluc%C3%ADa/cadiz/la-huelga-afecta-a-la-produccion-de-las-grandes-industrias-del-campo-de-gibraltar/1774573.html',
#    'url_mobile': 'https://amp.canalsur.es/noticias/andalucía/cadiz/la-huelga-afecta-a-la-produccion-de-las-grandes-industrias-del-campo-de-gibraltar/1774573.html',
#    'title': 'La huelga afecta a la producción de las grandes industrias del Campo de Gibraltar',
#    'seendate': '20211124T151500Z',
#    'socialimage': 'https://www.canalsur.es/resources/archivos_offline/2021/11/24/1637762344235tapa_empresas_begoa.jpg',
#    'domain': 'canalsur.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://prnoticias.com/2021/12/07/ibex-35-martes-7-diciembre-verde/',
#    'url_mobile': '',
#    'title': 'El Ibex 35 recupera la senda positiva',
#    'seendate': '20211207T101500Z',
#    'socialimage': 'https://prnoticias.com/wp-content/uploads/2020/03/8a04177ad408601c2fe4eccbc6911c77.jpg',
#    'domain': 'prnoticias.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://cronicadecantabria.com/cr/acerinox-aprueba-un-plan-de-recompra-de-acciones-para-amortizacin-de-hasta-un-4-de-su-capital/',
#    'url_mobile': '',
#    'title': 'Acerinox aprueba un plan de recompra de acciones para amortización de hasta un 4 % de su capital',
#    'seendate': '20211220T093000Z',
#    'socialimage': '',
#    'domain': 'cronicadecantabria.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.diariosigloxxi.com/texto-ep/mostrar/20211220093857/acerinox-aprueba-plan-recompra-acciones-amortizacion-hasta-4-capital',
#    'url_mobile': '',
#    'title': 'Acerinox aprueba un plan de recompra de acciones para amortización de hasta un 4 % de su capital',
#    'seendate': '20211220T090000Z',
#    'socialimage': 'http://img.europapress.net/fotoweb/fotonoticia_20211220093857_640.jpg',
#    'domain': 'diariosigloxxi.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elboletin.com/el-ibex-35-arranca-2022-con-ligeras-alzas-y-mantiene-los-8-700-puntos/',
#    'url_mobile': 'https://www.elboletin.com/el-ibex-35-arranca-2022-con-ligeras-alzas-y-mantiene-los-8-700-puntos/amp/',
#    'title': 'El Ibex 35 arranca 2022 con ligeras alzas y mantiene los 8 . 700 puntos',
#    'seendate': '20220103T233000Z',
#    'socialimage': 'https://www.elboletin.com/wp-content/uploads/2021/02/www.elboletin.com_fotos_1_147499__MG_9474.JPG',
#    'domain': 'elboletin.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elboletin.com/el-ibex-35-se-aleja-de-los-8-400-puntos-con-una-caida-del-042-a-media-sesion/',
#    'url_mobile': 'https://www.elboletin.com/el-ibex-35-se-aleja-de-los-8-400-puntos-con-una-caida-del-042-a-media-sesion/amp/',
#    'title': 'El Ibex 35 se aleja de los 8 . 400 puntos con una caída del 0 , 42 % a media sesión',
#    'seendate': '20211210T221500Z',
#    'socialimage': 'https://www.elboletin.com/wp-content/uploads/2021/02/www.elboletin.com_fotos_1_147356__MG_9341.JPG',
#    'domain': 'elboletin.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://cincodias.elpais.com/cincodias/2021/12/10/mercados/1639159954_102969.html',
#    'url_mobile': 'https://cincodias.elpais.com/cincodias/2021/12/10/mercados/1639159954_102969.amp.html',
#    'title': 'Diez valores para apostar por la Bolsa española | Mercados',
#    'seendate': '20211211T093000Z',
#    'socialimage': 'https://d500.epimg.net/cincodias/imagenes/2021/12/10/mercados/1639159954_102969_1639167725_rrss_normal.jpg',
#    'domain': 'cincodias.elpais.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/cinco-joyas-del-ibex-35-con-las-que-ganar-mas-n-491243',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/cinco-joyas-del-ibex-35-con-las-que-ganar-mas-n-491243',
#    'title': 'Cinco joyas del Ibex 35 con las que ganar más de un 50 % el próximo año',
#    'seendate': '20211201T070000Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/native/potencialbolsanative.png',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/diez-valores-del-ibex-35-con-un-potencial-de-mas-n-493677',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/diez-valores-del-ibex-35-con-un-potencial-de-mas-n-493677',
#    'title': 'Ibex 35 : los diez mejores valores del Ibex por potencial para 2022',
#    'seendate': '20220104T051500Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/native/valores_en_positivo.jpeg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.diariodeleon.es/articulo/bierzo/matriz-roldan-alerta-que-luz-resta-competividad/202201300334142186516.html',
#    'url_mobile': 'https://www.diariodeleon.es/articulo/bierzo/matriz-roldan-alerta-que-luz-resta-competividad/202201300334142186516.amp.html',
#    'title': 'La matriz de Roldán alerta de que la luz resta competividad',
#    'seendate': '20220130T074500Z',
#    'socialimage': 'https://www.diariodeleon.es/media/diariodeleon/images/2022/01/30/2022013002341424997.jpg',
#    'domain': 'diariodeleon.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.diariovasco.com/economia/mercados/ibex-recupera-8500-20211207090251-ntrc.html',
#    'url_mobile': 'https://www.diariovasco.com/economia/mercados/ibex-recupera-8500-20211207090251-ntrc_amp.html',
#    'title': 'El Ibex recupera los 8 . 500 puntos impulsado por las turísticas',
#    'seendate': '20211207T093000Z',
#    'socialimage': 'https://static.diariovasco.com/www/multimedia/202112/07/media/cortadas/ibex-efe-kF8F--984x468@RC.JPG',
#    'domain': 'diariovasco.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elboletin.com/las-empresas-espanolas-parten-en-la-pole-position-para-beneficiarse-del-plan-de-infraestructuras-de-biden/',
#    'url_mobile': 'https://www.elboletin.com/las-empresas-espanolas-parten-en-la-pole-position-para-beneficiarse-del-plan-de-infraestructuras-de-biden/amp/',
#    'title': 'Las empresas españolas parten en la  pole position  para beneficiarse del plan de infraestructuras de Biden',
#    'seendate': '20211109T011500Z',
#    'socialimage': 'https://www.elboletin.com/wp-content/uploads/2021/02/www.elboletin.com_fotos_1_147419_europapress-3527672-january-20-2021-washington-dc-united-states-united-states-president-joe.jpg',
#    'domain': 'elboletin.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.prnewswire.com/news-releases/74-of-growth-to-originate-from-apac-for-stainless-steel-market-upsurge-in-consumption-of-high-strength-stainless-steel-to-boost-growth--17000-technavio-reports-301458238.html',
#    'url_mobile': '',
#    'title': '74 % of Growth to Originate from APAC for Stainless Steel Market| Upsurge in Consumption of High - strength Stainless Steel to Boost Growth',
#    'seendate': '20220112T153000Z',
#    'socialimage': '',
#    'domain': 'prnewswire.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.prnewswire.com:443/news-releases/74-of-growth-to-originate-from-apac-for-stainless-steel-market-upsurge-in-consumption-of-high-strength-stainless-steel-to-boost-growth--17000-technavio-reports-301458238.html',
#    'url_mobile': '',
#    'title': '74 % of Growth to Originate from APAC for Stainless Steel Market| Upsurge in Consumption of High - strength Stainless Steel to Boost Growth',
#    'seendate': '20220112T153000Z',
#    'socialimage': '',
#    'domain': 'prnewswire.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.elconfidencial.com/mercados/2021-12-09/rovi-entra-ibex-sustitucion-viscofan_3338402/',
#    'url_mobile': 'https://www.elconfidencial.com/amp/mercados/2021-12-09/rovi-entra-ibex-sustitucion-viscofan_3338402/',
#    'title': 'Ibex 35 : Rovi entrará en el Ibex 35 en sustitución de Viscofan',
#    'seendate': '20211209T174500Z',
#    'socialimage': 'https://images.ecestaticos.com/wpD60LGMOxRhbeBJ1qstmDhdAXk=/0x0:2272x1704/600x315/filters:fill(white):format(jpg):watermark(f.elconfidencial.com/file/bae/eea/fde/baeeeafde1b3229287b0c008f7602058.png,0,274,1)/f.elconfidencial.com/original/d83/81f/80c/d8381f80ca06ede09b27603a32695669.jpg',
#    'domain': 'elconfidencial.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.newyorktelegraph.com/news/272238130/stainless-steel-market-2022-industry-size-trends-share-growth-analysis-and-forecast-to-2028',
#    'url_mobile': '',
#    'title': 'Stainless Steel Market 2022 , Industry Size , Trends , Share , Growth , Analysis and Forecast to 2028',
#    'seendate': '20220128T003000Z',
#    'socialimage': '',
#    'domain': 'newyorktelegraph.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.sandiegosun.com/news/272238130/stainless-steel-market-2022-industry-size-trends-share-growth-analysis-and-forecast-to-2028',
#    'url_mobile': '',
#    'title': 'Stainless Steel Market 2022 , Industry Size , Trends , Share , Growth , Analysis and Forecast to 2028',
#    'seendate': '20220128T000000Z',
#    'socialimage': '',
#    'domain': 'sandiegosun.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.texasguardian.com/news/272238130/stainless-steel-market-2022-industry-size-trends-share-growth-analysis-and-forecast-to-2028',
#    'url_mobile': '',
#    'title': 'Stainless Steel Market 2022 , Industry Size , Trends , Share , Growth , Analysis and Forecast to 2028',
#    'seendate': '20220127T233000Z',
#    'socialimage': '',
#    'domain': 'texasguardian.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.digitaljournal.com/pr/stainless-steel-market-is-booming-worldwide-with-acerinox-thyssen-krupp-aperam',
#    'url_mobile': '',
#    'title': 'Stainless Steel Market Is Booming Worldwide with Acerinox , Thyssen Krupp , Aperam',
#    'seendate': '20220127T194500Z',
#    'socialimage': 'https://cts.releasewire.com/v/?sid=1352495&s=y&v=f',
#    'domain': 'digitaljournal.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.elperiodico.com/es/economia/20220124/bolsa-lunes-24-enero-13143707',
#    'url_mobile': 'https://amp.elperiodico.com/es/economia/20220124/bolsa-lunes-24-enero-13143707',
#    'title': 'La bolsa del lunes 24 de enero',
#    'seendate': '20220124T231500Z',
#    'socialimage': 'https://est.elperiodico.com/ep-static/img/default-es-1260x708.jpg',
#    'domain': 'elperiodico.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://cincodias.elpais.com/cincodias/2021/12/13/mercados/1639379125_447671.html',
#    'url_mobile': 'https://cincodias.elpais.com/cincodias/2021/12/13/mercados/1639379125_447671.amp.html',
#    'title': 'El Ibex arranca con alzas la semana de los bancos centrales | Mercados',
#    'seendate': '20211213T084500Z',
#    'socialimage': 'https://d500.epimg.net/cincodias/imagenes/2021/12/13/mercados/1639379125_447671_1639379210_rrss_normal.jpg',
#    'domain': 'cincodias.elpais.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/mercados/cronica-bolsa/2022/01/20/61e9047d468aeb4e748b4608.html',
#    'url_mobile': 'https://amp.expansion.com/mercados/cronica-bolsa/2022/01/20/61e9047d468aeb4e748b4608.html',
#    'title': 'El Ibex intenta el rebote con el estreno de sus resultados',
#    'seendate': '20220120T071500Z',
#    'socialimage': 'https://phantom-expansion.unidadeditorial.es/55827560d397fdd2ff8d0294a7f8b9fa/crop/19x0/1744x1150/resize/1200/f/jpg/assets/multimedia/imagenes/2022/01/19/16426192256587.jpg',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://cincodias.elpais.com/cincodias/2021/11/17/mercados/1637173892_118438.html',
#    'url_mobile': 'https://cincodias.elpais.com/cincodias/2021/11/17/mercados/1637173892_118438.amp.html',
#    'title': 'Los seis valores que son una apuesta segura para los analistas | Mercados',
#    'seendate': '20211118T081500Z',
#    'socialimage': 'https://d500.epimg.net/cincodias/imagenes/2021/11/17/mercados/1637173892_118438_1637174217_rrss_normal.jpg',
#    'domain': 'cincodias.elpais.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://mundo.sputniknews.com/20211123/fuertes-enfrentamientos-entre-la-policia-y-los-trabajadores-del-metal-en-el-sur-de-espana-1118551289.html',
#    'url_mobile': 'https://mundo.sputniknews.com/amp/20211123/fuertes-enfrentamientos-entre-la-policia-y-los-trabajadores-del-metal-en-el-sur-de-espana-1118551289.html',
#    'title': 'Fuertes enfrentamientos entre la Policía y los trabajadores del metal en el sur de España',
#    'seendate': '20211123T164500Z',
#    'socialimage': 'https://cdnnmundo1.img.sputniknews.com/images/sharing/article/spa/1118551289.jpg',
#    'domain': 'mundo.sputniknews.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Russia'},
#   {'url': 'https://mundo.sputniknews.com/20211123/el-gobierno-espanol-afirma-que-confia-en-la-policia-pese-a-las-criticas-por-la-actuacion-en-cadiz-1118554341.html',
#    'url_mobile': 'https://mundo.sputniknews.com/amp/20211123/el-gobierno-espanol-afirma-que-confia-en-la-policia-pese-a-las-criticas-por-la-actuacion-en-cadiz-1118554341.html',
#    'title': 'El Gobierno español afirma que confía en la Policía pese a las críticas por la actuación en Cádiz',
#    'seendate': '20211123T174500Z',
#    'socialimage': 'https://cdnnmundo1.img.sputniknews.com/images/sharing/article/spa/1118554341.jpg',
#    'domain': 'mundo.sputniknews.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Russia'},
#   {'url': 'https://mundo.sputniknews.com/20211124/los-trabajadores-del-metal-del-sur-de-espana-encaran-una-nueva-jornada-de-movilizaciones-1118587981.html',
#    'url_mobile': 'https://mundo.sputniknews.com/amp/20211124/los-trabajadores-del-metal-del-sur-de-espana-encaran-una-nueva-jornada-de-movilizaciones-1118587981.html',
#    'title': 'Los trabajadores del metal del sur de España encaran una nueva jornada de movilizaciones',
#    'seendate': '20211124T131500Z',
#    'socialimage': 'https://cdnnmundo1.img.sputniknews.com/images/sharing/article/spa/1118587981.jpg',
#    'domain': 'mundo.sputniknews.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Russia'},
#   {'url': 'https://www.lainformacion.com/mercados-y-bolsas/ibex-cierra-noviembre-peor-mes-marzo-2020-situa-cola-europa/2854598/',
#    'url_mobile': 'https://amp.lainformacion.com/mercados-y-bolsas/ibex-cierra-noviembre-peor-mes-marzo-2020-situa-cola-europa/2854598/',
#    'title': 'El Ibex cierra su peor mes desde marzo de 2020 y se sitúa a la cola de Europa',
#    'seendate': '20211130T053000Z',
#    'socialimage': 'https://imagenes.lainformacion.com/files/og_lainfo/uploads/imagenes/2021/10/22/bolsa-de-madrid-ibex-35.jpeg',
#    'domain': 'lainformacion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elmundo.es/economia/2021/11/23/619d32e821efa0b9038b459e.html',
#    'url_mobile': 'https://amp.elmundo.es/economia/2021/11/23/619d32e821efa0b9038b459e.html',
#    'title': 'Cargas policiales e incidentes en la octava jornada de huelga del metal en Cádiz',
#    'seendate': '20211123T194500Z',
#    'socialimage': 'https://phantom-elmundo.unidadeditorial.es/d81f3bc0fdbe204685ebbea2199242d6/crop/0x0/3071x2047/resize/1200/f/jpg/assets/multimedia/imagenes/2021/11/23/16376916844046.jpg',
#    'domain': 'elmundo.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.europapress.es/economia/macroeconomia-00338/noticia-teresa-ribera-preside-encuentro-generacion-oportunidades-retos-desarrollo-sostenible-20220124083008.html',
#    'url_mobile': 'https://amp.europapress.es/economia/macroeconomia-00338/noticia-teresa-ribera-preside-encuentro-generacion-oportunidades-retos-desarrollo-sostenible-20220124083008.html',
#    'title': 'Teresa Ribera preside el encuentro de Generación de Oportunidades sobre los retos del desarrollo sostenible',
#    'seendate': '20220124T083000Z',
#    'socialimage': 'https://img.europapress.es/fotoweb/fotonoticia_20220124083008_1200.jpg',
#    'domain': 'europapress.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elperiodico.com/es/economia/20211125/gran-industria-pide-gobierno-triplicar-12900503',
#    'url_mobile': 'https://amp.elperiodico.com/es/economia/20211125/gran-industria-pide-gobierno-triplicar-12900503',
#    'title': 'La gran industria pide al Gobierno triplicar las ayudas de su factura de luz en plena subida',
#    'seendate': '20211125T110000Z',
#    'socialimage': 'https://estaticos-cdn.elperiodico.com/clip/9719f188-a2d3-419e-8df2-403765e6212a_16-9-aspect-ratio_default_0.jpg',
#    'domain': 'elperiodico.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.republica.com/2022/01/05/el-ibex-35-cede-un-006-y-vuelve-a-quedarse-por-debajo-de-los-8-800-puntos/',
#    'url_mobile': 'https://www.republica.com/2022/01/05/el-ibex-35-cede-un-006-y-vuelve-a-quedarse-por-debajo-de-los-8-800-puntos/amp/',
#    'title': 'El Ibex 35 cede un 0 , 06 % ',
#    'seendate': '20220105T210000Z',
#    'socialimage': 'https://www.republica.com/wp-content/uploads/2022/01/bolsa.jpg',
#    'domain': 'republica.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://mundo.sputniknews.com/20211119/enfrentamientos-entre-policia-y-trabajadores-en-el-cuarto-dia-de-huelga-en-cadiz-1118431845.html',
#    'url_mobile': 'https://mundo.sputniknews.com/amp/20211119/enfrentamientos-entre-policia-y-trabajadores-en-el-cuarto-dia-de-huelga-en-cadiz-1118431845.html',
#    'title': 'Enfrentamientos entre policía y trabajadores en el cuarto día de huelga en Cádiz',
#    'seendate': '20211119T161500Z',
#    'socialimage': 'https://cdnnmundo1.img.sputniknews.com/images/sharing/article/spa/1118431845.jpg',
#    'domain': 'mundo.sputniknews.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Russia'},
#   {'url': 'https://www.estrategiasdeinversion.com/entidad/analista-independiente',
#    'url_mobile': '',
#    'title': 'Noticias de Analista Independiente | Estrategias de Inversión',
#    'seendate': '20211116T111500Z',
#    'socialimage': '',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://noticiasbancarias.com/bolsa/12/01/2022/el-ibex-35-termina-el-miercoles-con-un-avance-del-016/252026.html',
#    'url_mobile': 'https://noticiasbancarias.com/bolsa/12/01/2022/el-ibex-35-termina-el-miercoles-con-un-avance-del-016/252026.html?amp',
#    'title': 'El Ibex 35 termina el miércoles con un avance del 0 , 16 % ',
#    'seendate': '20220113T000000Z',
#    'socialimage': '',
#    'domain': 'noticiasbancarias.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.europapress.es/economia/finanzas-00340/noticia-bbva-patrono-primera-catedra-interdisciplinar-hidrogeno-espana-20220127150752.html',
#    'url_mobile': 'https://amp.europapress.es/economia/finanzas-00340/noticia-bbva-patrono-primera-catedra-interdisciplinar-hidrogeno-espana-20220127150752.html',
#    'title': 'BBVA , patrono de la primera cátedra interdisciplinar sobre hidrógeno de España',
#    'seendate': '20220127T143000Z',
#    'socialimage': 'https://img.europapress.es/fotoweb/fotonoticia_20220127150752_1200.jpg',
#    'domain': 'europapress.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lainformacion.com/mercados-y-bolsas/berkeley-desploma-volver-cotizar-conflicto-fondo-oman/2852613/',
#    'url_mobile': 'https://amp.lainformacion.com/mercados-y-bolsas/berkeley-desploma-volver-cotizar-conflicto-fondo-oman/2852613/',
#    'title': 'Berkeley se desploma al volver a cotizar tras el conflicto con el fondo de Omán',
#    'seendate': '20211103T124500Z',
#    'socialimage': 'https://imagenes.lainformacion.com/files/og_lainfo/uploads/imagenes/2021/08/05/oficinas-de-berkeley-en-retortillo.jpeg',
#    'domain': 'lainformacion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://noticiasbancarias.com/bolsa/13/01/2022/ibex-35-repunte-del-053-al-cierre/252068.html',
#    'url_mobile': 'https://noticiasbancarias.com/bolsa/13/01/2022/ibex-35-repunte-del-053-al-cierre/252068.html?amp',
#    'title': 'Ibex 35 : Repunte del 0 , 53 % al cierre',
#    'seendate': '20220113T231500Z',
#    'socialimage': '',
#    'domain': 'noticiasbancarias.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://mundo.sputniknews.com/20211116/trabajadores-del-metal-comienzan-una-huelga-indefinida-en-el-sur-de-espana-1118284381.html',
#    'url_mobile': 'https://mundo.sputniknews.com/amp/20211116/trabajadores-del-metal-comienzan-una-huelga-indefinida-en-el-sur-de-espana-1118284381.html',
#    'title': 'Trabajadores del metal comienzan una huelga indefinida en el sur de España',
#    'seendate': '20211116T144500Z',
#    'socialimage': 'https://cdnnmundo1.img.sputniknews.com/images/sharing/article/spa/1118284381.jpg',
#    'domain': 'mundo.sputniknews.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Russia'},
#   {'url': 'https://mundo.sputniknews.com/20211118/los-trabajadores-del-metal-de-cadiz-toman-la-calle-en-la-tercera-jornada-de-huelga-1118400988.html',
#    'url_mobile': 'https://mundo.sputniknews.com/amp/20211118/los-trabajadores-del-metal-de-cadiz-toman-la-calle-en-la-tercera-jornada-de-huelga-1118400988.html',
#    'title': 'Los trabajadores del metal de Cádiz toman la calle en la tercera jornada de huelga',
#    'seendate': '20211118T201500Z',
#    'socialimage': 'https://cdnnmundo1.img.sputniknews.com/images/sharing/article/spa/1118400988.jpg',
#    'domain': 'mundo.sputniknews.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Russia'},
#   {'url': 'https://www.elboletin.com/el-ibex-35-se-deja-un-054-en-la-sesion-y-pierde-los-9-100-puntos/',
#    'url_mobile': 'https://www.elboletin.com/el-ibex-35-se-deja-un-054-en-la-sesion-y-pierde-los-9-100-puntos/amp/',
#    'title': 'El Ibex 35 se deja un 0 , 54 % en la sesión y pierde los 9 . 100 puntos',
#    'seendate': '20211111T233000Z',
#    'socialimage': 'https://www.elboletin.com/wp-content/uploads/2021/01/www.elboletin.com_fotos_1_146490__MG_9340.JPG',
#    'domain': 'elboletin.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.telesurtv.net/news/metalurgicos-inician-huelga-indefinida-cadiz-espana-salarios-20211116-0015.html',
#    'url_mobile': 'https://www.telesurtv.net/amp/news/metalurgicos-inician-huelga-indefinida-cadiz-espana-salarios-20211116-0015.html',
#    'title': 'Metalúrgicos inician huelga indefinida en Cádiz , España | Noticias',
#    'seendate': '20211116T170000Z',
#    'socialimage': 'https://www.telesurtv.net/__export/1637075545234/sites/telesur/img/2021/11/16/espaxa_huelga_metalxrgicos_cxdiz_sur_andalucxa_frente_a_planta_airbus_foto_efe.jpg_1689854195.jpg',
#    'domain': 'telesurtv.net',
#    'language': 'Spanish',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.lavozdegalicia.es/noticia/opinion/2022/01/29/danos-colaterales-inevitables/0003_202201G29P11993.htm',
#    'url_mobile': 'https://www.lavozdegalicia.es/amp/noticia/opinion/2022/01/29/danos-colaterales-inevitables/0003_202201G29P11993.htm',
#    'title': 'Daños colaterales inevitables',
#    'seendate': '20220129T050000Z',
#    'socialimage': 'https://www.lavozdegalicia.es/default/2022/01/28/00121643392922655285881/Foto/G17O8107.jpg',
#    'domain': 'lavozdegalicia.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.diariosur.es/economia/mercados/bolsa-recupera-semana-20211210191538-ntrc.html',
#    'url_mobile': 'https://www.diariosur.es/economia/mercados/bolsa-recupera-semana-20211210191538-ntrc_amp.html',
#    'title': 'La Bolsa recupera un 1 , 4 % en la semana',
#    'seendate': '20211210T221500Z',
#    'socialimage': 'https://static1.diariosur.es/www/multimedia/202112/10/media/cortadas/ibex1-kFdF--984x468@RC.JPG',
#    'domain': 'diariosur.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://cincodias.elpais.com/cincodias/2022/01/31/mercados/1643612379_457562.html',
#    'url_mobile': 'https://cincodias.elpais.com/cincodias/2022/01/31/mercados/1643612379_457562.amp.html',
#    'title': 'El Ibex arranca la semana con subidas y el petróleo al alza | Mercados',
#    'seendate': '20220131T101500Z',
#    'socialimage': 'https://d500.epimg.net/cincodias/imagenes/2022/01/31/mercados/1643612379_457562_1643612577_rrss_normal.jpg',
#    'domain': 'cincodias.elpais.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lamarea.com/2021/12/07/farmaceuticas-pharmamar-almirall-empresas-opacas-ibex-35/',
#    'url_mobile': '',
#    'title': 'Las farmacéuticas Pharmamar y Almirall son las empresas más  opacas  del IBEX 35',
#    'seendate': '20211207T150000Z',
#    'socialimage': 'https://agqcvcudno.cloudimg.io/v7/https://www.lamarea.com/wp-content/uploads/2021/12/tcardpharmamar.jpg',
#    'domain': 'lamarea.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lavozdeasturias.es/noticia/opinion/2022/01/29/danos-colaterales-inevitables/0003_202201G29P11993.htm',
#    'url_mobile': 'https://www.lavozdeasturias.es/amp/noticia/opinion/2022/01/29/danos-colaterales-inevitables/0003_202201G29P11993.htm',
#    'title': 'Daños colaterales inevitables',
#    'seendate': '20220129T124500Z',
#    'socialimage': 'https://www.lavozdeasturias.es/default/2022/01/28/00121643392922655285881/Foto/G17O8107.jpg',
#    'domain': 'lavozdeasturias.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lainformacion.com/mercados-y-bolsas/ibex-pelea-recuperar-8400-puntos-espera-dato-empleo-eeuu/2855006/',
#    'url_mobile': 'https://amp.lainformacion.com/mercados-y-bolsas/ibex-pelea-recuperar-8400-puntos-espera-dato-empleo-eeuu/2855006/',
#    'title': 'El Ibex 35 pelea por recuperar los 8 . 400 a la espera del dato de empleo en EEUU',
#    'seendate': '20211203T090000Z',
#    'socialimage': 'https://imagenes.lainformacion.com/files/og_lainfo/uploads/imagenes/2019/06/10/5cd05a12573fe.jpeg',
#    'domain': 'lainformacion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.hellenicshippingnews.com/eu-imposes-tariffs-on-stainless-steel-from-india-indonesia/',
#    'url_mobile': 'https://www.hellenicshippingnews.com/eu-imposes-tariffs-on-stainless-steel-from-india-indonesia/amp/',
#    'title': 'EU imposes tariffs on stainless steel from India , Indonesia | Hellenic Shipping News Worldwide',
#    'seendate': '20211119T204500Z',
#    'socialimage': '',
#    'domain': 'hellenicshippingnews.com',
#    'language': 'English',
#    'sourcecountry': 'China'},
#   {'url': 'https://www.elboletin.com/el-ibex-35-recupera-un-14-en-la-semana-aunque-termina-la-sesion-de-hoy-en-rojo/',
#    'url_mobile': 'https://www.elboletin.com/el-ibex-35-recupera-un-14-en-la-semana-aunque-termina-la-sesion-de-hoy-en-rojo/amp/',
#    'title': 'El Ibex 35 recupera un 1 , 4 % en la semana , aunque termina la sesión de hoy en rojo',
#    'seendate': '20211210T221500Z',
#    'socialimage': 'https://www.elboletin.com/wp-content/uploads/2021/02/www.elboletin.com_fotos_1_147653__MG_9265.JPG',
#    'domain': 'elboletin.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lainformacion.com/mercados-y-bolsas/ibex-perdidas-semana-reunion-fed-ucrania/2858288/',
#    'url_mobile': 'https://amp.lainformacion.com/mercados-y-bolsas/ibex-perdidas-semana-reunion-fed-ucrania/2858288/',
#    'title': 'El Ibex abre en rojo la semana marcada por la reunión de la Fed y Ucrania',
#    'seendate': '20220124T090000Z',
#    'socialimage': 'https://imagenes.lainformacion.com/files/og_lainfo/uploads/imagenes/2018/10/29/5bd5f28437a3a.jpeg',
#    'domain': 'lainformacion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/la-pandemia-cambia-la-cara-del-ibex-35-y-el-sector-n-492163',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/la-pandemia-cambia-la-cara-del-ibex-35-y-el-sector-n-492163',
#    'title': 'El Covid - 19 cambia la cara del Ibex 35 y las farmacéuticas ganan presencia',
#    'seendate': '20211213T143000Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/native/ibex-35.jpeg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.nexotrans.com/noticia/103994/expertos-corroboran-el-papel-del-hidrogeno-renovable-como-vector-energetico.html',
#    'url_mobile': 'https://www.nexotrans.com/mvc/amp/noticia/103994/',
#    'title': 'Expertos corroboran el papel del hidrógeno renovable como vector energético',
#    'seendate': '20220131T094500Z',
#    'socialimage': 'https://www.nexotrans.com/fotos/1/Esperanza_Montero_CM_-_CaA_tedra_H2_ICADE.jpg',
#    'domain': 'nexotrans.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.20minutos.es/noticia/4895395/0/que-piden-trabajadores-metal-cadiz-huelga/',
#    'url_mobile': 'https://amp.20minutos.es/noticia/4895395/0/que-piden-trabajadores-metal-cadiz-huelga/',
#    'title': 'Qué piden los trabajadores del metal de Cádiz en la huelga',
#    'seendate': '20211118T093000Z',
#    'socialimage': 'https://imagenes.20minutos.es/files/og_20m/uploads/imagenes/2021/11/17/huelga-metal-cadiz.jpeg',
#    'domain': '20minutos.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.cope.es/actualidad/economia/noticias/bolsa-deja-llevar-por-abulia-cierra-como-farolillo-rojo-las-plazas-europeas-20211108_1604303',
#    'url_mobile': 'https://www.cope.es/actualidad/economia/amp/noticias/bolsa-deja-llevar-por-abulia-cierra-como-farolillo-rojo-las-plazas-europeas-20211108_1604303',
#    'title': 'La Bolsa se deja llevar por la abulia y cierra como el farolillo rojo de las plazas europeas',
#    'seendate': '20211108T173000Z',
#    'socialimage': 'https://cope-cdnmed.agilecontent.com/resources/jpg/0/9/1636368906590.jpg',
#    'domain': 'cope.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lainformacion.com/mercados-y-bolsas/ibex-rebote-giro-alcista-wall-street/2858387/',
#    'url_mobile': 'https://amp.lainformacion.com/mercados-y-bolsas/ibex-rebote-giro-alcista-wall-street/2858387/',
#    'title': 'El Ibex 35 tira de rebote en busca de los 8 . 500 tras el giro alcista de Wall Street',
#    'seendate': '20220125T120000Z',
#    'socialimage': 'https://imagenes.lainformacion.com/files/og_lainfo/uploads/imagenes/2019/11/06/5d1ef830ac361.jpeg',
#    'domain': 'lainformacion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.expansion.com/blogs/escenario-tecnico/2021/11/21/ventas-en-el-ibex-y-en-su-version-total.html',
#    'url_mobile': 'https://amp.expansion.com/blogs/escenario-tecnico/2021/11/21/ventas-en-el-ibex-y-en-su-version-total.html',
#    'title': 'Escenario técnico de mercados - Ventas en el Ibex y en su versión total return . ¿ Y entonces ? ',
#    'seendate': '20211121T131500Z',
#    'socialimage': 'https://e00-expansion.uecdn.es/assets/desktop/master/img/blogs/foto_peq_gerardoortega.png',
#    'domain': 'expansion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.lemonde.fr/international/article/2022/01/27/en-espagne-la-hausse-des-prix-nourrit-une-vague-de-conflits-sociaux_6111292_3210.html',
#    'url_mobile': '',
#    'title': 'En Espagne , la hausse des prix nourrit une vague de conflits sociaux',
#    'seendate': '20220127T210000Z',
#    'socialimage': 'https://img.lemde.fr/2022/01/26/579/0/4505/2250/1440/720/60/0/c6543f3_205598497-greve-metallurgie-espagne.jpg',
#    'domain': 'lemonde.fr',
#    'language': 'French',
#    'sourcecountry': 'France'},
#   {'url': 'https://www.europapress.es/economia/bolsa-00348/noticia-ibex-35-deja-casi-media-sesion-pendiente-situacion-ucrania-rusia-20220124122619.html',
#    'url_mobile': 'https://amp.europapress.es/economia/bolsa-00348/noticia-ibex-35-deja-casi-media-sesion-pendiente-situacion-ucrania-rusia-20220124122619.html',
#    'title': 'El Ibex 35 se deja casi un 2 % en la media sesión , pendiente de la situación entre Ucrania y Rusia',
#    'seendate': '20220124T120000Z',
#    'socialimage': 'https://img.europapress.es/fotoweb/fotonoticia_20220124122619_1200.jpg',
#    'domain': 'europapress.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.prnewswire.com:443/news-releases/additive-market-recovery-still-strong-in-q3-2021-according-to-smartech-analysis-latest-data-market-set-for-biggest-q4-in-history-301439179.html',
#    'url_mobile': '',
#    'title': 'Additive Market Recovery Still Strong in Q3 2021 According to SmarTech Analysi Latest Data , Market Set for Biggest Q4 in History',
#    'seendate': '20211207T154500Z',
# ...
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elperiodico.com/es/economia/20211115/ricos-espanoles-pasan-renovables-dan-12847511',
#    'url_mobile': 'https://amp.elperiodico.com/es/economia/20211115/ricos-espanoles-pasan-renovables-dan-12847511',
#    'title': 'Los ricos españoles se pasan a las renovables que ya dan más que la bolsa y el ladrillo',
#    'seendate': '20211115T124500Z',
#    'socialimage': 'https://estaticos-cdn.elperiodico.com/clip/b69d54b4-0163-416b-bf7f-5fcc050193e7_16-9-aspect-ratio_default_0.jpg',
#    'domain': 'elperiodico.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.digitaljournal.com/pr/stainless-steel-market-size-revenue-growth-trends-and-company-strategy-analysis-by-2027',
#    'url_mobile': '',
#    'title': 'Stainless Steel Market Size , Revenue Growth Trends and Company Strategy Analysis by 2027',
#    'seendate': '20220201T141500Z',
#    'socialimage': '',
#    'domain': 'digitaljournal.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.estrategiasdeinversion.com/analisis/bolsa-y-mercados/analisis-fondos/bestinver-ve-potencial-en-facebook-alibaba-tencent-n-495711',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/bestinver-ve-potencial-en-facebook-alibaba-tencent-n-495711',
#    'title': 'Bestinver ve potencial en Facebook , Microsoft , Alibaba , Tencent y Samsung',
#    'seendate': '20220126T144500Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/Portada2/tomas-pinto.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.bignewsnetwork.com/news/271993344/global-stainless-steel-plate-market-2021-growth-factor---tisco-aperam-baosteel-outokumpu',
#    'url_mobile': '',
#    'title': 'Global Stainless Steel Plate Market 2021 Growth factor - Tisco , Aperam , BAOSTEEL , Outokumpu',
#    'seendate': '20211221T143000Z',
#    'socialimage': '',
#    'domain': 'bignewsnetwork.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.20minutos.es/noticia/4900943/0/huelga-del-metal-en-cadiz-la-penultima-rebelion-de-una-provincia-instalada-en-una-crisis-interminable/',
#    'url_mobile': 'https://amp.20minutos.es/noticia/4900943/0/huelga-del-metal-en-cadiz-la-penultima-rebelion-de-una-provincia-instalada-en-una-crisis-interminable/',
#    'title': 'Huelga del metal en Cádiz : la penúltima rebelión de una provincia instalada en una crisis interminable',
#    'seendate': '20211124T104500Z',
#    'socialimage': 'https://imagenes.20minutos.es/files/og_20m/uploads/imagenes/2021/11/22/ugt-encara-la-tercera-reunion-en-sevilla-con-la-ilusion-de-cerrar-un-acuerdo-para-acabar-la-huelga-del-metal.jpeg',
#    'domain': '20minutos.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.bignewsnetwork.com/news/271762851/global-steel-for-automotive-and-aerospace-market-2021-revenue-opportunity-forecast-and-value-chain-2027',
#    'url_mobile': '',
#    'title': 'Global Steel for Automotive and Aerospace Market 2021 Revenue , Opportunity , Forecast and Value Chain 2027',
#    'seendate': '20211119T150000Z',
#    'socialimage': '',
#    'domain': 'bignewsnetwork.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.finanznachrichten.de/nachrichten-2021-11/54625790-stainless-steel-market-to-reach-usd-171050-by-2027-at-a-cagr-of-4-6-valuates-reports-008.htm',
#    'url_mobile': '',
#    'title': 'Stainless Steel Market to Reach USD 171050 by 2027 at a CAGR of 4 . 6 % ',
#    'seendate': '20211130T153000Z',
#    'socialimage': '',
#    'domain': 'finanznachrichten.de',
#    'language': 'English',
#    'sourcecountry': 'Germany'},
#   {'url': 'https://www.lainformacion.com/mercados-y-bolsas/donde-invertir-gordo-navidad-rentabilidad/2856146/',
#    'url_mobile': 'https://amp.lainformacion.com/mercados-y-bolsas/donde-invertir-gordo-navidad-rentabilidad/2856146/',
#    'title': '  Me ha tocado : ¿ dónde invertir el Gordo de Navidad para rentabilizarlo ? ',
#    'seendate': '20211221T050000Z',
#    'socialimage': 'https://imagenes.lainformacion.com/files/og_lainfo/uploads/imagenes/2020/12/22/loteria-de-navidad-2020-28.jpeg',
#    'domain': 'lainformacion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'http://www.blackseagrain.net/2022/01/27/stainless-steel-flat-products-market-future-demand-market-analysis-and-outlook-to-2027/',
#    'url_mobile': '',
#    'title': 'Stainless Steel Flat Products Market Future Demand , Market Analysis and Outlook to 2027',
#    'seendate': '20220127T021500Z',
#    'socialimage': '',
#    'domain': 'blackseagrain.net',
#    'language': 'English',
#    'sourcecountry': 'Ukraine'},
#   {'url': 'https://thetimeshub.in/in-spain-the-rise-in-prices-fuels-a-wave-of-social-conflicts',
#    'url_mobile': 'https://thetimeshub.in/in-spain-the-rise-in-prices-fuels-a-wave-of-social-conflicts/amp',
#    'title': 'In Spain , the rise in prices fuels a wave of social conflicts',
#    'seendate': '20220128T100000Z',
#    'socialimage': 'https://thetimeshub.in/wp-content/uploads/2022/01/a86e2b8a38240ae2eb4dfa39060fd1a3.jpg',
#    'domain': 'thetimeshub.in',
#    'language': 'English',
#    'sourcecountry': ''},
#   {'url': 'https://www.wsws.org/en/articles/2021/11/19/pode-n19.html',
#    'url_mobile': '',
#    'title': 'PSOE - Podemos sends police to attack Spanish metalworkers strike in Cádiz',
#    'seendate': '20211119T043000Z',
#    'socialimage': 'https://www.wsws.org/asset/efdd1506-669b-419c-a219-3aaa3afe3a3a?rendition=image1280',
#    'domain': 'wsws.org',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'http://www.comunicati.net/comunicati/arte/varie/755954.html',
#    'url_mobile': '',
#    'title': 'Stainless Steel Market is estimated to expand at a CAGR of 5 . 5 % during the forecast period of 2021 - 2031',
#    'seendate': '20220127T141500Z',
#    'socialimage': '',
#    'domain': 'comunicati.net',
#    'language': 'English',
#    'sourcecountry': 'Italy'},
#   {'url': 'https://www.elconfidencial.com/empresas/2021-11-24/montero-salvo-medel-dietas-contra-criterio-consejo-consultivo_3329483/',
#    'url_mobile': '',
#    'title': 'Noticias de Unicaja : Montero salvó a Medel y sus dietas en contra del criterio del Consejo Consultivo',
#    'seendate': '20211124T054500Z',
#    'socialimage': 'https://images.ecestaticos.com/DHXe1QYckA3doa8c23M9lXQ_Ejc=/0x0:2272x1624/600x315/filters:fill(white):format(jpg):watermark(f.elconfidencial.com/file/bae/eea/fde/baeeeafde1b3229287b0c008f7602058.png,0,274,1)/f.elconfidencial.com/original/8cb/30d/337/8cb30d337c94bef4c4d17f8a7b06a6db.jpg',
#    'domain': 'elconfidencial.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://agmetalminer.com/author/kbenchinaolsen/',
#    'url_mobile': '',
#    'title': 'Katie Benchina Olsen',
#    'seendate': '20220110T211500Z',
#    'socialimage': '',
#    'domain': 'agmetalminer.com',
#    'language': 'English',
#    'sourcecountry': 'China'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/telefonica-y-bbva-lideran-las-subidas-en-el-ibex-n-490313',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/telefonica-y-bbva-lideran-las-subidas-en-el-ibex-n-490313',
#    'title': 'BBVA y Telefónica llevan al Ibex 35 por encima de los 8 . 940 puntos',
#    'seendate': '20211119T084500Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/images/amp/bolsa-madrid-3.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.diariodeferrol.com/texto-diario/mostrar/3312274/conflicto-metal-cadiz-encalla-cuatro-dias-consecutivos-huelga',
#    'url_mobile': '',
#    'title': 'El conflicto del metal de Cádiz encalla tras cuatro días consecutivos de huelga',
#    'seendate': '20211119T193000Z',
#    'socialimage': 'http://www.diariodeferrol.com/images/showid/4975116',
#    'domain': 'diariodeferrol.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.elidealgallego.com/texto-diario/mostrar/3312273/conflicto-metal-cadiz-encalla-cuatro-dias-consecutivos-huelga',
#    'url_mobile': '',
#    'title': 'El conflicto del metal de Cádiz encalla tras cuatro días consecutivos de huelga',
#    'seendate': '20211119T220000Z',
#    'socialimage': 'http://www.elidealgallego.com/images/showid/4975112',
#    'domain': 'elidealgallego.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/el-ibex-35-sube-mas-de-un-1-y-supera-la-cota-de-n-493645',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/el-ibex-35-sube-mas-de-un-1-y-supera-la-cota-de-n-493645',
#    'title': 'El Ibex 35 supera los 8 . 800 puntos | Estrategias de Inversión',
#    'seendate': '20220103T140000Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/Portada2/bolsa-espanola.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.eldiariodechihuahua.mx/opinion/-electrocuto-negocio-a-despedidos-en-la-uach-20211102-1858248.html',
#    'url_mobile': 'https://www.eldiariodechihuahua.mx/opinion/amp/-electrocuto-negocio-a-despedidos-en-la-uach-20211102-1858248.html?fbclid=IwAR23x4dO8zeDtbdifknKDtu2gj3RftI5osuFjMfy4ESu6uKvPCByYIBjX4A',
#    'title': ' - Electrocutó negocio a despedidos en la UACH',
#    'seendate': '20211103T090000Z',
#    'socialimage': 'https://www.eldiariodechihuahua.mx/chih/media/uploads/galeria/2021/11/02/20211102091507708-0-1858248.jpeg',
#    'domain': 'eldiariodechihuahua.mx',
#    'language': 'Spanish',
#    'sourcecountry': 'Mexico'},
#   {'url': 'https://pda.kp.ru/daily/28353/4500877/',
#    'url_mobile': 'https://amp.kp.ru/daily/28353/4500877/',
#    'title': 'Какие интриги плетутся на подмостках Москвы : Вместо Ширвиндта - Газаров , вместо Женовача - Хабенский',
#    'seendate': '20211108T163000Z',
#    'socialimage': '',
#    'domain': 'pda.kp.ru',
#    'language': 'Russian',
#    'sourcecountry': ''},
#   {'url': 'https://cincodias.elpais.com/cincodias/2021/12/14/fondos_y_planes/1639479577_786555.html',
#    'url_mobile': 'https://cincodias.elpais.com/cincodias/2021/12/14/fondos_y_planes/1639479577_786555.amp.html',
#    'title': 'Estrategias para rentabilizar las carteras en 2022 | Fondos y Planes',
#    'seendate': '20211215T110000Z',
#    'socialimage': 'https://d500.epimg.net/cincodias/imagenes/2021/12/14/fondos_y_planes/1639479577_786555_1639481779_rrss_normal.jpg',
#    'domain': 'cincodias.elpais.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.estrategiasdeinversion.com/actualidad/noticias/bolsa-espana/el-ibex-35-estira-el-rally-de-navidad-y-supera-n-493727',
#    'url_mobile': 'https://www.estrategiasdeinversion.com/amp/el-ibex-35-estira-el-rally-de-navidad-y-supera-n-493727',
#    'title': 'El Ibex 35 supera la cota de los 8 . 800 con todos sus valores al alza',
#    'seendate': '20220104T100000Z',
#    'socialimage': 'https://www.estrategiasdeinversion.com/uploads/noticias_redaccion/Portada2/panel_ibex_35.jpg',
#    'domain': 'estrategiasdeinversion.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.vozpopuli.com/economia_y_finanzas/murtra-sanchez-indra.html',
#    'url_mobile': 'https://www.vozpopuli.com/economia_y_finanzas/murtra-sanchez-indra.html?amp=1',
#    'title': 'Marc Murtra se pega a Pedro Sánchez para lograr la presidencia ejecutiva de Indra',
#    'seendate': '20220123T044500Z',
#    'socialimage': 'https://media.vozpopuli.com/2022/01/21/indra-murtra.png',
#    'domain': 'vozpopuli.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://cronicadecantabria.com/cr/el-ibex-35-se-revaloriza-un-79-en-un-ao-marcado-por-la-volatilidad-derivada-de-la-pandemia-y-la-inflacin/',
#    'url_mobile': '',
#    'title': 'El Ibex 35 se revaloriza un 7 , 9 % en un año marcado por la volatilidad derivada de la pandemia y la inflación',
#    'seendate': '20211230T221500Z',
#    'socialimage': '',
#    'domain': 'cronicadecantabria.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://www.diariodepontevedra.es/articulo/economia/urgen-medidas-frente-coste-energetico-es-rentable-producir-precios/202201110011411180148.html',
#    'url_mobile': 'https://www.diariodepontevedra.es/articulo/economia/urgen-medidas-frente-coste-energetico-es-rentable-producir-precios/202201110011411180148.amp.html',
#    'title': '  Urgen medidas frente al coste energético ; no es rentable producir a estos precios  ',
#    'seendate': '20220111T001500Z',
#    'socialimage': 'https://www.diariodepontevedra.es/media/diariodepontevedra/images/2022/01/11/2022011100113213371.jpg',
#    'domain': 'diariodepontevedra.es',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'http://www.comunicati.net/comunicati/aziende/tecnologia/739901.html',
#    'url_mobile': '',
#    'title': 'Alloy Steel Market Report 2021 - Outokumpu , Shanxi TISCO , Tsingshan , Acerinox',
#    'seendate': '20211111T101500Z',
#    'socialimage': '',
#    'domain': 'comunicati.net',
#    'language': 'English',
#    'sourcecountry': 'Italy'},
#   {'url': 'http://www.comunicati.net/comunicati/aziende/tecnologia/750782.html',
#    'url_mobile': '',
#    'title': 'Austenitic Alloys Tubes Market Report 2021 - Outokumpu , Aperam Stainless , Sandvik , Acerinox , Nippon Steel & Sumitomo Metal',
#    'seendate': '20211231T083000Z',
#    'socialimage': '',
#    'domain': 'comunicati.net',
#    'language': 'English',
#    'sourcecountry': 'Italy'},
#   {'url': 'https://www.vozpopuli.com/opinion/establishment-badajoz.html',
#    'url_mobile': 'https://www.vozpopuli.com/opinion/establishment-badajoz.html?amp=1',
#    'title': 'El establishment y un señor de Badajoz',
#    'seendate': '20211226T053000Z',
#    'socialimage': 'https://media.vozpopuli.com/2021/12/26/establishment-badajoz.jpg',
#    'domain': 'vozpopuli.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Spain'},
#   {'url': 'https://industrialit.com.au/lean-duplex-stainless-steel-market-size-2021-analysis-by-top-key-players-outokumpu-oyj-finlandtata-steel-indiajindal-steel-indiaarcelormittal-s-a-luxembourg/',
#    'url_mobile': '',
#    'title': 'Lean Duplex Stainless Steel Market Size 2021 Analysis by Top Key Players | Outokumpu Oyj ( Finland ), Tata Steel ( India ), Jindal Steel ( India ), ArcelorMittal S . A . ( Luxembourg ) – Industrial IT',
#    'seendate': '20220106T164500Z',
#    'socialimage': '',
#    'domain': 'industrialit.com.au',
#    'language': 'English',
#    'sourcecountry': 'Australia'},
#   {'url': 'https://www.sova-center.ru/misuse/news/persecution/2021/11/d45295/',
#    'url_mobile': '',
#    'title': 'В Дагестане суд прекратил производство по ряду дел об участии в деятельности экстремистской организации / Ноябрь / 2021 / Преследования организаций , СМИ и частных лиц / Новости / Неправомерный антиэкстремизм / СОВА',
#    'seendate': '20211119T151500Z',
#    'socialimage': '',
#    'domain': 'sova-center.ru',
#    'language': 'Russian',
#    'sourcecountry': 'Russia'},
#   {'url': 'https://www.anred.org/2021/11/17/espana-represion-y-lucha-en-el-primer-dia-de-huelga-de-las-y-los-trabajadores-metalurgicos-de-cadiz/',
#    'url_mobile': '',
#    'title': 'España : represión y lucha en el primer día de huelga de las y los trabajadores metalúrgicos de Cádiz – ANRed',
#    'seendate': '20211117T170000Z',
#    'socialimage': 'https://www.anred.org/wp-content/uploads/2021/11/Huelga-metalurgicos-Cadiz-0.jpg',
#    'domain': 'anred.org',
#    'language': 'Spanish',
#    'sourcecountry': 'Argentina'},
#   {'url': 'http://libcom.org/history/wildcat-spain-encounters-democracy-1976-1978',
#    'url_mobile': '',
#    'title': 'Wildcat Spain encounters democracy , 1976 - 1978 - Los Incontrolados',
#    'seendate': '20220103T160000Z',
#    'socialimage': 'http://libcom.org/files/Lois%20workers%20assembly.jpg',
#    'domain': 'libcom.org',
#    'language': 'English',
#    'sourcecountry': 'United States'}]}

# %% [markdown]
# https://medium.com/@jasonrigden/using-tor-with-the-python-request-library-79015b2606cb
